# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
tfds.load('gov_report', with_info=True,data_dir="content/govreport")
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Shuffling content/govreport/gov_report/crs_whitespace/1.0.0.incompleteABLQEX/gov_report-train.tfrecord*...:   …
# Generating validation examples...:   0%|          | 0/362 [00:00<?, ? examples/s]
# Shuffling content/govreport/gov_report/crs_whitespace/1.0.0.incompleteABLQEX/gov_report-validation.tfrecord*..…
# Generating test examples...:   0%|          | 0/362 [00:00<?, ? examples/s]
# Shuffling content/govreport/gov_report/crs_whitespace/1.0.0.incompleteABLQEX/gov_report-test.tfrecord*...:   0…
# Dataset gov_report downloaded and prepared to content/govreport/gov_report/crs_whitespace/1.0.0. Subsequent calls will reuse this data.
# ...
